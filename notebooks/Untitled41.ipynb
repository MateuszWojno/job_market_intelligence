# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
SRC_PATH = PROJECT_ROOT / "src"

if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from nfj import (
    collect_job_urls,
    scrape_jobs,
    scrape_one_job
)

print("PROJECT_ROOT:", PROJECT_ROOT)
print("SRC_PATH:", SRC_PATH)
print("Import OK")
# Out:
# PROJECT_ROOT: G:\pandas\job_market_intelligence
# SRC_PATH: G:\pandas\job_market_intelligence\src
# Import OK

# %%
import nfj

print(
    "collect_job_urls:",
    hasattr(nfj, "collect_job_urls")
)

print(
    "scrape_jobs:",
    hasattr(nfj, "scrape_jobs")
)

print(
    "scrape_one_job:",
    hasattr(nfj, "scrape_one_job")
)
# Out:
# collect_job_urls: True
# scrape_jobs: True
# scrape_one_job: True

# %%
df_urls, df_stats = collect_job_urls(
    categories=["data"],
    max_pages_per_category=2,
    delay=1.0,
    headless=False
)
# Out:
# ...
# KATEGORIA: data
# ...
#
# Strona 1:
# https://nofluffjobs.com/pl/data?page=1
# URL-i na stronie: 20
# Nowych w kategorii: 20
# Unikalnych w kategorii: 20
# Łącznie globalnie: 20
#
# Strona 2:
# https://nofluffjobs.com/pl/data?page=2
# URL-i na stronie: 40
# Nowych w kategorii: 20
# Unikalnych w kategorii: 40
# Łącznie globalnie: 40
#
# ...
# ZBIERANIE URL-I ZAKOŃCZONE
# ...
# Łącznie unikalnych URL-i: 40
#
# Statystyki:
#   category  category_urls  new_global_urls  total_urls
# 0     data             40               40          40
#
# Zapisano URL-e:
# G:\pandas\job_market_intelligence\data\raw\nofluff_it_urls.csv

# %%
print("Amount URL-s:", len(df_urls))

display(df_urls.head())

display(df_stats)
# Out:
# Amount URL-s: 40
#                                                  url
# 0  https://nofluffjobs.com/pl/job/architekt-danyc...
# 1  https://nofluffjobs.com/pl/job/architekt-danyc...
# 2  https://nofluffjobs.com/pl/job/azure-data-plat...
# 3  https://nofluffjobs.com/pl/job/business-analys...
# 4  https://nofluffjobs.com/pl/job/data-analyst-ew...
#   category  category_urls  new_global_urls  total_urls
# 0     data             40               40          40

# %%
print("Amount URL-i:", len(df_urls))

display(df_urls.head())

display(df_stats)
# Out:
# Amount URL-i: 40
#                                                  url
# 0  https://nofluffjobs.com/pl/job/architekt-danyc...
# 1  https://nofluffjobs.com/pl/job/architekt-danyc...
# 2  https://nofluffjobs.com/pl/job/azure-data-plat...
# 3  https://nofluffjobs.com/pl/job/business-analys...
# 4  https://nofluffjobs.com/pl/job/data-analyst-ew...
#   category  category_urls  new_global_urls  total_urls
# 0     data             40               40          40

# %%
print(
    "Duplicated URL:",
    df_urls["url"].duplicated().sum()
)
# Out:
# Duplicated URL: 0

# %%
df_test = scrape_jobs(
    max_jobs=5,
    delay=1.0,
    headless=False
)
# Out:
# URL-i do sprawdzenia: 5
# Już pobranych: 5
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_test = scrape_jobs(
#       2     max_jobs=5,
#       3     delay=1.0,
#       4     headless=False
#       5 )
#
# File G:\pandas\job_market_intelligence\src\nfj\scraper.py:298, in scrape_jobs(urls_path, output_path, error_path, max_jobs, delay, checkpoint_every, headless)
#     292             print(
#     293                 f"Zapisano: "
#     294                 f"{len(df_checkpoint)}"
#     295             )
#     297 finally:
# --> 298     df_final = save_results(
#     299         results,
#     300         output_path
#     301     )
#     303     save_errors(
#     304         errors,
#     305         error_path
#     306     )
#     308     driver.quit()
#
# ...

# %%
df_test

# %%
df_test.columns.tolist()

# %%
columns_to_check = [
    "title",
    "company",
    "category",
    "experience",
    "experience_years_min",
    "workplace",
    "job_locations",
    "salary_min",
    "salary_max",
    "salary_currency",
    "contract_type"
]

display(
    df_test[columns_to_check]
)

# %%
df_urls, df_stats = collect_job_urls(
    delay=1.0,
    headless=False
)

# %%
from nfj.config import DATA_DIR

TEST_OUTPUT_PATH = DATA_DIR / "nofluff_test_jobs.csv"
TEST_ERROR_PATH = DATA_DIR / "nofluff_test_errors.csv"

df_test = scrape_jobs(
    max_jobs=5,
    delay=1.0,
    headless=False,
    output_path=TEST_OUTPUT_PATH,
    error_path=TEST_ERROR_PATH
)

# %%
print("Liczba ofert:", len(df_test))

display(
    df_test[
        [
            "title",
            "company",
            "category",
            "experience",
            "experience_years_min",
            "workplace",
            "job_locations",
            "salary_min",
            "salary_max",
            "salary_currency",
            "contract_type"
        ]
    ]
)

# %%
df_test.T

# %%
df_jobs = scrape_jobs()
# Out:
# URL-i do sprawdzenia: 40
# Już pobranych: 5
#
# ...
# [6/40]
# https://nofluffjobs.com/pl/job/data-analyst-scalo-warszawa-4
# OK: Data Analyst
# Company: Scalo
# Category: Data
#
# ...
# [7/40]
# https://nofluffjobs.com/pl/job/data-architect-connectis--warszawa-4
# OK: Data Architect
# Company: Connectis_
# Category: Data
#
# ...
# [8/40]
# https://nofluffjobs.com/pl/job/data-catalog-documentation-specialist-square-one-resources-remote
# OK: Data Catalog & Documentation Specialist
# Company: Square One Resources
# Category: Data
#
# ...
# [9/40]
# https://nofluffjobs.com/pl/job/data-engineer-gcp-connectis--warszawa-5
# OK: Data Engineer GCP
# Company: Connectis_
# Category: Data
#
# ...
# [10/40]
# https://nofluffjobs.com/pl/job/data-governance-expert-upvanta-warszawa
# OK: Data Governance Expert
# Company: None
# Category: Data
#
# ...
# [11/40]
# https://nofluffjobs.com/pl/job/data-platform-developer-kafka-upvanta-remote
# OK: Data Platform Developer (Kafka)
# Company: None
# Category: Data
#
# ...
# [12/40]
# ...

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
SRC_PATH = PROJECT_ROOT / "src"

if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from nfj import scrape_jobs
from nfj.config import DATA_DIR

print("Import OK")
# Out:
# Import OK

# %%
TEST_OUTPUT_PATH = DATA_DIR / "nofluff_test_jobs_v3.csv"
TEST_ERROR_PATH = DATA_DIR / "nofluff_test_errors_v3.csv"

df_test = scrape_jobs(
    max_jobs=5,
    delay=1.0,
    headless=False,
    output_path=TEST_OUTPUT_PATH,
    error_path=TEST_ERROR_PATH
)
# Out:
# URL-i do sprawdzenia: 5
# Już pobranych: 0
#
# ...
# [1/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-data-platform-praca-hybrydowa-moondigo-warszawa
# OK: Architekt Danych / Tech Lead Data Platform (praca hybrydowa)
# Company: Moondigo Sp. z o.o.
# Category: Data
#
# ...
# [2/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-k-m-astek-polska-warszawa
# OK: Architekt Danych / Tech Lead K/M
# Company: None
# Category: Data
#
# ...
# [3/5]
# https://nofluffjobs.com/pl/job/azure-data-platform-engineer-m-f-stackmine-remote
# OK: Azure Data Platform Engineer [M/F]
# Company: Stackmine
# Category: Data
#
# ...
# [4/5]
# https://nofluffjobs.com/pl/job/business-analyst-mindbox-krakow-26
# OK: Business Analyst
# Company: None
# Category: Data
#
# ...
# [5/5]
# https://nofluffjobs.com/pl/job/data-analyst-ework-group-gdansk-4
# OK: Data Analyst
# Company: Ework Group
# Category: Data
#
# ...
# SCRAPING ZAKOŃCZONY
# ...
# Łącznie ofert: 5
# Nowo pobranych: 5
# Błędów: 0
#
# CSV:
# ...

# %%
df_test.T
# Out:
#                                                                       0  \
# job_id                architekt-danych-tech-lead-data-platform-praca...
# url                   https://nofluffjobs.com/pl/job/architekt-danyc...
# title                 Architekt Danych / Tech Lead Data Platform (pr...
# category                                                           Data
# experience                                                       Senior
# experience_years_min                                               10.0
# workplace                                                        Hybrid
# job_locations                                                      None
# company                                             Moondigo Sp. z o.o.
# company_size                                                    10 - 49
# company_founded                                                  2023.0
# company_locations                                                Warsaw
# ...

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
SRC_PATH = PROJECT_ROOT / "src"

if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from nfj import scrape_jobs
from nfj.config import DATA_DIR

# %%
TEST_OUTPUT_PATH = DATA_DIR / "nofluff_test_jobs_v4.csv"
TEST_ERROR_PATH = DATA_DIR / "nofluff_test_errors_v4.csv"

df_test = scrape_jobs(
    max_jobs=5,
    delay=1.0,
    headless=False,
    output_path=TEST_OUTPUT_PATH,
    error_path=TEST_ERROR_PATH
)
# Out:
# URL-i do sprawdzenia: 5
# Już pobranych: 0
#
# ...
# [1/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-data-platform-praca-hybrydowa-moondigo-warszawa
# OK: Architekt Danych / Tech Lead Data Platform (praca hybrydowa)
# Company: Moondigo Sp. z o.o.
# Category: Data
#
# ...
# [2/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-k-m-astek-polska-warszawa
# OK: Architekt Danych / Tech Lead K/M
# Company: None
# Category: Data
#
# ...
# [3/5]
# https://nofluffjobs.com/pl/job/azure-data-platform-engineer-m-f-stackmine-remote
# OK: Azure Data Platform Engineer [M/F]
# Company: Stackmine
# Category: Data
#
# ...
# [4/5]
# https://nofluffjobs.com/pl/job/business-analyst-mindbox-krakow-26
# OK: Business Analyst
# Company: None
# Category: Data
#
# ...
# [5/5]
# https://nofluffjobs.com/pl/job/data-analyst-ework-group-gdansk-4
# OK: Data Analyst
# Company: Ework Group
# Category: Data
#
# ...
# SCRAPING ZAKOŃCZONY
# ...
# Łącznie ofert: 5
# Nowo pobranych: 5
# Błędów: 0
#
# CSV:
# ...

# %%
df_test.T
# Out:
#                                                                       0  \
# job_id                architekt-danych-tech-lead-data-platform-praca...
# url                   https://nofluffjobs.com/pl/job/architekt-danyc...
# title                 Architekt Danych / Tech Lead Data Platform (pr...
# category                                                           Data
# experience                                                       Senior
# experience_years_min                                                7.0
# workplace                                                        Hybrid
# job_locations                                                  Warszawa
# company                                             Moondigo Sp. z o.o.
# company_size                                                    10 - 49
# company_founded                                                  2023.0
# company_locations                                                Warsaw
# ...

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
SRC_PATH = PROJECT_ROOT / "src"

if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from nfj import scrape_jobs
from nfj.config import DATA_DIR

# %%
TEST_OUTPUT_PATH = DATA_DIR / "nofluff_test_jobs_v5.csv"
TEST_ERROR_PATH = DATA_DIR / "nofluff_test_errors_v5.csv"

df_test = scrape_jobs(
    max_jobs=5,
    delay=1.0,
    headless=False,
    output_path=TEST_OUTPUT_PATH,
    error_path=TEST_ERROR_PATH
)
# Out:
# URL-i do sprawdzenia: 5
# Już pobranych: 0
#
# ...
# [1/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-data-platform-praca-hybrydowa-moondigo-warszawa
# OK: Architekt Danych / Tech Lead Data Platform (praca hybrydowa)
# Company: Moondigo Sp. z o.o.
# Category: Data
#
# ...
# [2/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-k-m-astek-polska-warszawa
# OK: Architekt Danych / Tech Lead K/M
# Company: None
# Category: Data
#
# ...
# [3/5]
# https://nofluffjobs.com/pl/job/azure-data-platform-engineer-m-f-stackmine-remote
# OK: Azure Data Platform Engineer [M/F]
# Company: Stackmine
# Category: Data
#
# ...
# [4/5]
# https://nofluffjobs.com/pl/job/business-analyst-mindbox-krakow-26
# OK: Business Analyst
# Company: None
# Category: Data
#
# ...
# [5/5]
# https://nofluffjobs.com/pl/job/data-analyst-ework-group-gdansk-4
# OK: Data Analyst
# Company: Ework Group
# Category: Data
#
# ...
# SCRAPING ZAKOŃCZONY
# ...
# Łącznie ofert: 5
# Nowo pobranych: 5
# Błędów: 0
#
# CSV:
# ...

# %%
df_test.T
# Out:
#                                                                       0  \
# job_id                architekt-danych-tech-lead-data-platform-praca...
# url                   https://nofluffjobs.com/pl/job/architekt-danyc...
# title                 Architekt Danych / Tech Lead Data Platform (pr...
# category                                                           Data
# experience                                                       Senior
# experience_years_min                                                7.0
# workplace                                                        Hybrid
# job_locations                                                  Warszawa
# company                                             Moondigo Sp. z o.o.
# company_size                                                    10 - 49
# company_founded                                                  2023.0
# company_locations                                                Warsaw
# ...

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
SRC_PATH = PROJECT_ROOT / "src"

if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from nfj import scrape_jobs
from nfj.config import DATA_DIR

# %%
TEST_OUTPUT_PATH = DATA_DIR / "nofluff_test_jobs_v6.csv"
TEST_ERROR_PATH = DATA_DIR / "nofluff_test_errors_v6.csv"

df_test = scrape_jobs(
    max_jobs=5,
    delay=1.0,
    headless=False,
    output_path=TEST_OUTPUT_PATH,
    error_path=TEST_ERROR_PATH
)
# Out:
# URL-i do sprawdzenia: 5
# Już pobranych: 0
#
# ...
# [1/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-data-platform-praca-hybrydowa-moondigo-warszawa
# OK: Architekt Danych / Tech Lead Data Platform (praca hybrydowa)
# Company: Moondigo Sp. z o.o.
# Category: Data
#
# ...
# [2/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-k-m-astek-polska-warszawa
# OK: Architekt Danych / Tech Lead K/M
# Company: Architekt Danych / Tech Lead K/M
# Category: Data
#
# ...
# [3/5]
# https://nofluffjobs.com/pl/job/azure-data-platform-engineer-m-f-stackmine-remote
# OK: Azure Data Platform Engineer [M/F]
# Company: Stackmine
# Category: Data
#
# ...
# [4/5]
# https://nofluffjobs.com/pl/job/business-analyst-mindbox-krakow-26
# OK: Business Analyst
# Company: Business Analyst
# Category: Data
#
# ...
# [5/5]
# https://nofluffjobs.com/pl/job/data-analyst-ework-group-gdansk-4
# OK: Data Analyst
# Company: Ework Group
# Category: Data
#
# ...
# SCRAPING ZAKOŃCZONY
# ...
# Łącznie ofert: 5
# Nowo pobranych: 5
# ...

# %%
df_test.T
# Out:
#                                                                       0  \
# job_id                architekt-danych-tech-lead-data-platform-praca...
# url                   https://nofluffjobs.com/pl/job/architekt-danyc...
# title                 Architekt Danych / Tech Lead Data Platform (pr...
# category                                                           Data
# experience                                                       Senior
# experience_years_min                                                7.0
# workplace                                                        Hybrid
# job_locations                                                  Warszawa
# company                                             Moondigo Sp. z o.o.
# company_size                                                    10 - 49
# company_founded                                                  2023.0
# company_locations                                                Warsaw
# ...

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
SRC_PATH = PROJECT_ROOT / "src"

if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from nfj import scrape_jobs
from nfj.config import DATA_DIR

# %%
TEST_OUTPUT_PATH = DATA_DIR / "nofluff_test_jobs_v7.csv"
TEST_ERROR_PATH = DATA_DIR / "nofluff_test_errors_v7.csv"

df_test = scrape_jobs(
    max_jobs=5,
    delay=1.0,
    headless=False,
    output_path=TEST_OUTPUT_PATH,
    error_path=TEST_ERROR_PATH
)
# Out:
# URL-i do sprawdzenia: 5
# Już pobranych: 0
#
# ...
# [1/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-data-platform-praca-hybrydowa-moondigo-warszawa
# OK: Architekt Danych / Tech Lead Data Platform (praca hybrydowa)
# Company: Moondigo Sp. z o.o.
# Category: Data
#
# ...
# [2/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-k-m-astek-polska-warszawa
# OK: Architekt Danych / Tech Lead K/M
# Company: Architekt Danych / Tech Lead K/M
# Category: Data
#
# ...
# [3/5]
# https://nofluffjobs.com/pl/job/azure-data-platform-engineer-m-f-stackmine-remote
# OK: Azure Data Platform Engineer [M/F]
# Company: Stackmine
# Category: Data
#
# ...
# [4/5]
# https://nofluffjobs.com/pl/job/business-analyst-mindbox-krakow-26
# OK: Business Analyst
# Company: Business Analyst
# Category: Data
#
# ...
# [5/5]
# https://nofluffjobs.com/pl/job/data-analyst-ework-group-gdansk-4
# OK: Data Analyst
# Company: Ework Group
# Category: Data
#
# ...
# SCRAPING ZAKOŃCZONY
# ...
# Łącznie ofert: 5
# Nowo pobranych: 5
# ...

# %%
df_test.T
# Out:
#                                                                       0  \
# job_id                architekt-danych-tech-lead-data-platform-praca...
# url                   https://nofluffjobs.com/pl/job/architekt-danyc...
# title                 Architekt Danych / Tech Lead Data Platform (pr...
# category                                                           Data
# experience                                                       Senior
# experience_years_min                                                7.0
# workplace                                                        Hybrid
# job_locations                                                  Warszawa
# company                                             Moondigo Sp. z o.o.
# company_size                                                    10 - 49
# company_founded                                                  2023.0
# company_locations                                                Warsaw
# ...

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
SRC_PATH = PROJECT_ROOT / "src"

if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from nfj import scrape_jobs
from nfj.config import DATA_DIR

# %%
TEST_OUTPUT_PATH = DATA_DIR / "nofluff_test_jobs_v8.csv"
TEST_ERROR_PATH = DATA_DIR / "nofluff_test_errors_v8.csv"

df_test = scrape_jobs(
    max_jobs=5,
    delay=1.0,
    headless=False,
    output_path=TEST_OUTPUT_PATH,
    error_path=TEST_ERROR_PATH
)
# Out:
# URL-i do sprawdzenia: 5
# Już pobranych: 0
#
# ...
# [1/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-data-platform-praca-hybrydowa-moondigo-warszawa
# OK: Architekt Danych / Tech Lead Data Platform (praca hybrydowa)
# Company: Moondigo Sp. z o.o.
# Category: Data
#
# ...
# [2/5]
# https://nofluffjobs.com/pl/job/architekt-danych-tech-lead-k-m-astek-polska-warszawa
# OK: Architekt Danych / Tech Lead K/M
# Company: ASTEK Polska
# Category: Data
#
# ...
# [3/5]
# https://nofluffjobs.com/pl/job/azure-data-platform-engineer-m-f-stackmine-remote
# OK: Azure Data Platform Engineer [M/F]
# Company: Stackmine
# Category: Data
#
# ...
# [4/5]
# https://nofluffjobs.com/pl/job/business-analyst-mindbox-krakow-26
# OK: Business Analyst
# Company: Mindbox Sp. z o.o.
# Category: Data
#
# ...
# [5/5]
# https://nofluffjobs.com/pl/job/data-analyst-ework-group-gdansk-4
# OK: Data Analyst
# Company: Ework Group
# Category: Data
#
# ...
# SCRAPING ZAKOŃCZONY
# ...
# Łącznie ofert: 5
# Nowo pobranych: 5
# Błędów: 0
#
# CSV:
# ...

# %%
df_test.T
# Out:
#                                                                       0  \
# job_id                architekt-danych-tech-lead-data-platform-praca...
# url                   https://nofluffjobs.com/pl/job/architekt-danyc...
# title                 Architekt Danych / Tech Lead Data Platform (pr...
# category                                                           Data
# experience                                                       Senior
# experience_years_min                                                7.0
# workplace                                                        Hybrid
# job_locations                                                  Warszawa
# company                                             Moondigo Sp. z o.o.
# company_size                                                    10 - 49
# company_founded                                                  2023.0
# company_locations                                                Warsaw
# ...

# %%
from nfj import collect_job_urls

df_urls, df_stats = collect_job_urls(
    delay=1.0,
    headless=False
)
# Out:
# ...
# KATEGORIA: it
# ...
#
# Strona 1:
# https://nofluffjobs.com/pl/it?page=1
# URL-i na stronie: 20
# Nowych w kategorii: 20
# Unikalnych w kategorii: 20
# Łącznie globalnie: 20
#
# Strona 2:
# https://nofluffjobs.com/pl/it?page=2
# URL-i na stronie: 40
# Nowych w kategorii: 20
# Unikalnych w kategorii: 40
# Łącznie globalnie: 40
#
# Strona 3:
# https://nofluffjobs.com/pl/it?page=3
# URL-i na stronie: 60
# Nowych w kategorii: 20
# Unikalnych w kategorii: 60
# Łącznie globalnie: 60
#
# Strona 4:
# https://nofluffjobs.com/pl/it?page=4
# URL-i na stronie: 80
# Nowych w kategorii: 20
# Unikalnych w kategorii: 80
# Łącznie globalnie: 80
#
# Strona 5:
# https://nofluffjobs.com/pl/it?page=5
# URL-i na stronie: 100
# Nowych w kategorii: 20
# Unikalnych w kategorii: 100
# Łącznie globalnie: 100
#
# Strona 6:
# https://nofluffjobs.com/pl/it?page=6
# URL-i na stronie: 85
# Nowych w kategorii: 85
# Unikalnych w kategorii: 185
# Łącznie globalnie: 185
#
# Strona 7:
# https://nofluffjobs.com/pl/it?page=7
# ...

# %%
len(df_urls)
# Out:
# 3286

# %%
from nfj import scrape_jobs

df_jobs = scrape_jobs(
    delay=1.0,
    headless=False
)
# Out:
# URL-i do sprawdzenia: 3286
# Już pobranych: 40
#
# ...
# [1/3286]
# https://nofluffjobs.com/pl/job/24-7-support-entry-level-acaisoft-remote
# OK: 24/7 Support – Entry Level
# Company: Acaisoft
# Category: Support
#
# ...
# [2/3286]
# https://nofluffjobs.com/pl/job/ad-operations-coordinator-emea-xperi-warszawa
# OK: Ad Operations Coordinator - EMEA
# Company: Xperi
# Category: Product Management
#
# ...
# [3/3286]
# https://nofluffjobs.com/pl/job/administrator-cybersecurity-scalo-warszawa
# OK: Administrator Cybersecurity
# Company: Scalo
# Category: Security
#
# ...
# [4/3286]
# https://nofluffjobs.com/pl/job/administrator-it-iteo-katowice
# OK: Administrator IT
# Company: iteo S.A.
# Category: None
#
# ...
# [5/3286]
# https://nofluffjobs.com/pl/job/administrator-ka-aplikacji-biznesowych-departament-it-t-mobile-polska-warszawa
# OK: Administrator/-ka Aplikacji Biznesowych - Departament IT
# Company: T-Mobile Polska
# Category: Support
#
# ...
# [6/3286]
# ...

# %%
import pandas as pd
from nfj.config import URLS_PATH, OUTPUT_PATH

df_urls = pd.read_csv(URLS_PATH)
df_jobs = pd.read_csv(OUTPUT_PATH)

print("URL-e:", len(df_urls))
print("Unikalne URL-e:", df_urls["url"].nunique())

print()
print("Oferty:", len(df_jobs))
print("Unikalne oferty:", df_jobs["url"].nunique())

print()
print(
    "Brakujące URL-e:",
    len(
        set(df_urls["url"])
        - set(df_jobs["url"])
    )
)
# Out:
# URL-e: 3286
# Unikalne URL-e: 3286
#
# Oferty: 3286
# Unikalne oferty: 3286
#
# Brakujące URL-e: 0
